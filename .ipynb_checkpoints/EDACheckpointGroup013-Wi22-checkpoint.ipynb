# %% [markdown]
# # COGS 108 - EDA Checkpoint

# %% [markdown]
# # Names
#
# - Ant Man
# - Hulk
# - Iron Man
# - Thor
# - Wasp

# %% [markdown]
# <a id='research_question'></a>
# # Research Question

# %% [markdown]
# *Fill in your research question here*

# %% [markdown]
# # Setup

# %%
import pandas as pd
import numpy as np
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
from tqdm import tqdm # progress bar for .apply()

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Describe your data cleaning steps here.

# %%
disaster2015 = pd.read_csv('datasets/nat_disast_bystate_deaths_cost/disaster_2015.csv')
disaster2015
# Out:
#    2015 Summary of Hazardous Weather Fatalities, Injuries, and Damage Costs by State  \
# 0                                               State
# 1                                                 NaN
# 2                                                 NaN
# 3                                         AK (Alaska)
# 4                                        AL (Alabama)
# ..                                                ...
# 67                                     WI (Wisconsin)
# 68                                 WV (West Virginia)
# 69                                       WY (Wyoming)
# 70                                              Total
# 71             Report generated: 5/13/2016 3:42:33 PM
#
#     Unnamed: 1 Unnamed: 2   Unnamed: 3   Unnamed: 4   Unnamed: 5
# 0   Fatalities   Injuries     Property         Crop        Total
# 1          NaN        NaN       Damage       Damage       Damage
# 2          NaN        NaN  (million $)  (million $)  (million $)
# 3            7          8           25            0           25
# 4           13         17        14.79            0        14.79
# ..         ...        ...          ...          ...          ...
# 67           4          8         8.73         0.01         8.74
# 68           4          2        20.73            0        20.73
# 69           2          5        10.35         0.25         10.6
# 70         522       2143      4202.01       645.11      4847.12
# 71         NaN        NaN          NaN          NaN        6 / 6
#
# [72 rows x 6 columns]

# %%
# rename columns
disaster2015.columns = ['state', 'fatalities', 'injuries', 'property_damage', 'crop_damage',
                       'total_damage']
disaster2015.columns
# Out:
# Index(['state', 'fatalities', 'injuries', 'property_damage', 'crop_damage',
#        'total_damage'],
#       dtype='object')

# %%
disaster2015
# Out:
#                                      state  fatalities  injuries  \
# 0                                    State  Fatalities  Injuries
# 1                                      NaN         NaN       NaN
# 2                                      NaN         NaN       NaN
# 3                              AK (Alaska)           7         8
# 4                             AL (Alabama)          13        17
# ..                                     ...         ...       ...
# 67                          WI (Wisconsin)           4         8
# 68                      WV (West Virginia)           4         2
# 69                            WY (Wyoming)           2         5
# 70                                   Total         522      2143
# 71  Report generated: 5/13/2016 3:42:33 PM         NaN       NaN
#
#    property_damage  crop_damage total_damage
# 0         Property         Crop        Total
# 1           Damage       Damage       Damage
# 2      (million $)  (million $)  (million $)
# 3               25            0           25
# 4            14.79            0        14.79
# ..             ...          ...          ...
# 67            8.73         0.01         8.74
# 68           20.73            0        20.73
# 69           10.35         0.25         10.6
# 70         4202.01       645.11      4847.12
# 71             NaN          NaN        6 / 6
#
# [72 rows x 6 columns]

# %%
# delete first three rows and last two rows of original dataframe
disaster2015 = disaster2015.drop(labels= [0, 1, 2, 70, 71])

# %%
disaster2015 = disaster2015.reset_index(drop= True)
disaster2015
# Out:
#                   state fatalities injuries property_damage crop_damage  \
# 0           AK (Alaska)          7        8              25           0
# 1          AL (Alabama)         13       17           14.79           0
# 2   AM (Atlantic South)          3        0               0           0
# 3   AN (Atlantic North)          4        5               0           0
# 4         AR (Arkansas)         10      337           18.25       27.26
# ..                  ...        ...      ...             ...         ...
# 62         VT (Vermont)          0        0            3.55           0
# 63      WA (Washington)          8        7           28.94        0.02
# 64       WI (Wisconsin)          4        8            8.73        0.01
# 65   WV (West Virginia)          4        2           20.73           0
# 66         WY (Wyoming)          2        5           10.35        0.25
#
#    total_damage
# 0            25
# 1         14.79
# 2             0
# 3             0
# 4         45.51
# ..          ...
# 62         3.55
# 63        28.96
# 64         8.74
# 65        20.73
# 66         10.6
#
# [67 rows x 6 columns]

# %%
# check for missing values
disaster2015.isna().sum()
# Out:
# state              0
# fatalities         1
# injuries           1
# property_damage    1
# crop_damage        1
# total_damage       0
# dtype: int64

# %%
# find rows that have missing values
disaster2015[disaster2015.isnull().any(axis=1)]
# Out:
#                                      state fatalities injuries  \
# 39  Report generated: 5/13/2016 3:42:33 PM        NaN      NaN
#
#    property_damage crop_damage total_damage
# 39             NaN         NaN        5 / 6

# %%
disaster2015 = disaster2015.drop(39)
disaster2015
# Out:
#                   state fatalities injuries property_damage crop_damage  \
# 0           AK (Alaska)          7        8              25           0
# 1          AL (Alabama)         13       17           14.79           0
# 2   AM (Atlantic South)          3        0               0           0
# 3   AN (Atlantic North)          4        5               0           0
# 4         AR (Arkansas)         10      337           18.25       27.26
# ..                  ...        ...      ...             ...         ...
# 62         VT (Vermont)          0        0            3.55           0
# 63      WA (Washington)          8        7           28.94        0.02
# 64       WI (Wisconsin)          4        8            8.73        0.01
# 65   WV (West Virginia)          4        2           20.73           0
# 66         WY (Wyoming)          2        5           10.35        0.25
#
#    total_damage
# 0            25
# 1         14.79
# 2             0
# 3             0
# 4         45.51
# ..          ...
# 62         3.55
# 63        28.96
# 64         8.74
# 65        20.73
# 66         10.6
#
# [66 rows x 6 columns]

# %%
disaster2015.isna().sum()
# Out:
# state              0
# fatalities         0
# injuries           0
# property_damage    0
# crop_damage        0
# total_damage       0
# dtype: int64

# %%
disaster2015.dtypes
# Out:
# state              object
# fatalities         object
# injuries           object
# property_damage    object
# crop_damage        object
# total_damage       object
# dtype: object

# %%
disaster2015.loc[0]
# Out:
# state              AK (Alaska)
# fatalities                   7
# injuries                     8
# property_damage             25
# crop_damage                  0
# total_damage                25
# Name: 0, dtype: object

# %%
type(disaster2015.loc[0][1])
# Out:
# str

# %%
# convert columns to correct data types
disaster2015[['fatalities','injuries', 'property_damage','crop_damage', 'total_damage']] = disaster2015[['fatalities','injuries', 'property_damage','crop_damage', 'total_damage']].apply(pd.to_numeric)

# %%
disaster2015.dtypes
# Out:
# state               object
# fatalities           int64
# injuries             int64
# property_damage    float64
# crop_damage        float64
# total_damage       float64
# dtype: object

# %%
disaster2015
# Out:
#                   state  fatalities  injuries  property_damage  crop_damage  \
# 0           AK (Alaska)           7         8            25.00         0.00
# 1          AL (Alabama)          13        17            14.79         0.00
# 2   AM (Atlantic South)           3         0             0.00         0.00
# 3   AN (Atlantic North)           4         5             0.00         0.00
# 4         AR (Arkansas)          10       337            18.25        27.26
# ..                  ...         ...       ...              ...          ...
# 62         VT (Vermont)           0         0             3.55         0.00
# 63      WA (Washington)           8         7            28.94         0.02
# 64       WI (Wisconsin)           4         8             8.73         0.01
# 65   WV (West Virginia)           4         2            20.73         0.00
# 66         WY (Wyoming)           2         5            10.35         0.25
#
#     total_damage
# 0          25.00
# 1          14.79
# 2           0.00
# 3           0.00
# 4          45.51
# ..           ...
# 62          3.55
# 63         28.96
# 64          8.74
# 65         20.73
# 66         10.60
#
# [66 rows x 6 columns]

# %%
disaster2015['state'].unique()
# Out:
# array(['AK (Alaska)', 'AL (Alabama)', 'AM (Atlantic South)',
#        'AN (Atlantic North)', 'AR (Arkansas)', 'AS (American Samoa)',
#        'AZ (Arizona)', 'CA (California)', 'CO (Colorado)',
#        'CT (Connecticut)', 'DC (District of Columbia)', 'DE (Delaware)',
#        'FL (Florida)', 'GA (Georgia)', 'GM (Gulf of Mexico)', 'GU (Guam)',
#        'HI (Hawaii)', 'IA (Iowa)', 'ID (Idaho)', 'IL (Illinois)',
#        'IN (Indiana)', 'KS (Kansas)', 'KY (Kentucky)', 'LA (Louisiana)',
#        'LC (Lake St.Clair)', 'LE (Lake Erie)', 'LH (Lake Huron)',
#        'LM (Lake Michigan)', 'LO (Lake Ontario)', 'LS (Lake Superior)',
#        'MA (Massachusetts)', 'MD (Maryland)', 'ME (Maine)',
#        'MI (Michigan)', 'MN (Minnesota)', 'MO (Missouri)',
#        'MS (Mississippi)', 'MT (Montana)', 'NC (North Carolina)',
#        'ND (North Dakota)', 'NE (Nebraska)', 'NH (New Hampshire)',
#        'NJ (New Jersey)', 'NM (New Mexico)', 'NV (Nevada)',
#        'NY (New York)', 'OH (Ohio)', 'OK (Oklahoma)', 'OR (Oregon)',
#        'PA (Pennsylvania)', 'PH (Hawaii Waters)', 'PR (Puerto Rico)',
#        'PZ (East Pacific)', 'RI (Rhode Island)', 'SC (South Carolina)',
#        'SD (South Dakota)', 'TN (Tennessee)', 'TX (Texas)', 'UT (Utah)',
#        'VA (Virginia)', 'VI (Virgin Islands)', 'VT (Vermont)',
#        'WA (Washington)', 'WI (Wisconsin)', 'WV (West Virginia)',
#        'WY (Wyoming)'], dtype=object)

# %%
# non_states = ['AM (Atlantic South)','AN (Atlantic North)', 'AS (American Samoa)',
#              'DC (District of Columbia)', 'GM (Gulf of Mexico)']

# %%
# disaster2015[disaster2015['state'] != 'AM (Atlantic South)' | 
#              disaster2015['state'] != 'AN (Atlantic North)' |
#             disaster2015['state'] != 'AS (American Samoa)']

# %%
disaster2020 = pd.read_csv('datasets/nat_disast_bystate_deaths_cost/disaster_2020.csv')
disaster2020
# Out:
#    2020 Summary of Hazardous Weather Fatalities, Injuries, and Damage Costs by State  \
# 0                                               State
# 1                                                 NaN
# 2                                                 NaN
# 3                                         AK (Alaska)
# 4                                        AL (Alabama)
# ..                                                ...
# 66                                    WA (Washington)
# 67                                     WI (Wisconsin)
# 68                                 WV (West Virginia)
# 69                                       WY (Wyoming)
# 70                                              Total
#
#     Unnamed: 1 Unnamed: 2   Unnamed: 3   Unnamed: 4   Unnamed: 5
# 0   Fatalities   Injuries     Property         Crop        Total
# 1          NaN        NaN       Damage       Damage       Damage
# 2          NaN        NaN  (million $)  (million $)  (million $)
# 3            5          0        35.85            0        35.85
# 4           11         27       313.39         2.08       315.47
# ..         ...        ...          ...          ...          ...
# 66           5         11      1340.16         0.52      1340.68
# 67          11          1        79.28         0.26        79.54
# 68           1          3         5.62            0         5.62
# 69           0          0         0.03            0         0.03
# 70         457       1425     26801.89       509.24     27311.13
#
# [71 rows x 6 columns]

# %%
# rename columns
disaster2020.columns = ['state', 'fatalities', 'injuries', 'property_damage', 'crop_damage',
                       'total_damage']
disaster2020.columns
# Out:
# Index(['state', 'fatalities', 'injuries', 'property_damage', 'crop_damage',
#        'total_damage'],
#       dtype='object')

# %%
disaster2020
# Out:
#                  state  fatalities  injuries property_damage  crop_damage  \
# 0                State  Fatalities  Injuries        Property         Crop
# 1                  NaN         NaN       NaN          Damage       Damage
# 2                  NaN         NaN       NaN     (million $)  (million $)
# 3          AK (Alaska)           5         0           35.85            0
# 4         AL (Alabama)          11        27          313.39         2.08
# ..                 ...         ...       ...             ...          ...
# 66     WA (Washington)           5        11         1340.16         0.52
# 67      WI (Wisconsin)          11         1           79.28         0.26
# 68  WV (West Virginia)           1         3            5.62            0
# 69        WY (Wyoming)           0         0            0.03            0
# 70               Total         457      1425        26801.89       509.24
#
#    total_damage
# 0         Total
# 1        Damage
# 2   (million $)
# 3         35.85
# 4        315.47
# ..          ...
# 66      1340.68
# 67        79.54
# 68         5.62
# 69         0.03
# 70     27311.13
#
# [71 rows x 6 columns]

# %%
# delete first three rows and last row of original dataframe
disaster2020 = disaster2020.drop(labels= [0, 1, 2, 70])

# %%
disaster2020
# Out:
#                   state fatalities injuries property_damage crop_damage  \
# 3           AK (Alaska)          5        0           35.85           0
# 4          AL (Alabama)         11       27          313.39        2.08
# 5   AM (Atlantic South)          0        0               0           0
# 6   AN (Atlantic North)          0        0            0.01           0
# 7         AR (Arkansas)          2       32          313.81        1.41
# ..                  ...        ...      ...             ...         ...
# 65         VT (Vermont)          0        0            1.91        0.01
# 66      WA (Washington)          5       11         1340.16        0.52
# 67       WI (Wisconsin)         11        1           79.28        0.26
# 68   WV (West Virginia)          1        3            5.62           0
# 69         WY (Wyoming)          0        0            0.03           0
#
#    total_damage
# 3         35.85
# 4        315.47
# 5             0
# 6          0.01
# 7        315.21
# ..          ...
# 65         1.92
# 66      1340.68
# 67        79.54
# 68         5.62
# 69         0.03
#
# [67 rows x 6 columns]

# %%
disaster2020 = disaster2020.reset_index(drop= True)
disaster2020
# Out:
#                   state fatalities injuries property_damage crop_damage  \
# 0           AK (Alaska)          5        0           35.85           0
# 1          AL (Alabama)         11       27          313.39        2.08
# 2   AM (Atlantic South)          0        0               0           0
# 3   AN (Atlantic North)          0        0            0.01           0
# 4         AR (Arkansas)          2       32          313.81        1.41
# ..                  ...        ...      ...             ...         ...
# 62         VT (Vermont)          0        0            1.91        0.01
# 63      WA (Washington)          5       11         1340.16        0.52
# 64       WI (Wisconsin)         11        1           79.28        0.26
# 65   WV (West Virginia)          1        3            5.62           0
# 66         WY (Wyoming)          0        0            0.03           0
#
#    total_damage
# 0         35.85
# 1        315.47
# 2             0
# 3          0.01
# 4        315.21
# ..          ...
# 62         1.92
# 63      1340.68
# 64        79.54
# 65         5.62
# 66         0.03
#
# [67 rows x 6 columns]

# %%
# check for missing values
disaster2020.isna().sum()
# Out:
# state              0
# fatalities         0
# injuries           0
# property_damage    0
# crop_damage        0
# total_damage       0
# dtype: int64

# %%
disaster2020.dtypes
# Out:
# state              object
# fatalities         object
# injuries           object
# property_damage    object
# crop_damage        object
# total_damage       object
# dtype: object

# %%
# convert columns to correct data types
disaster2020[['fatalities','injuries', 'property_damage','crop_damage', 'total_damage']] = disaster2020[['fatalities','injuries', 'property_damage','crop_damage', 'total_damage']].apply(pd.to_numeric)

# %%
disaster2020.dtypes
# Out:
# state               object
# fatalities           int64
# injuries             int64
# property_damage    float64
# crop_damage        float64
# total_damage       float64
# dtype: object

# %%
disaster2020
# Out:
#                   state  fatalities  injuries  property_damage  crop_damage  \
# 0           AK (Alaska)           5         0            35.85         0.00
# 1          AL (Alabama)          11        27           313.39         2.08
# 2   AM (Atlantic South)           0         0             0.00         0.00
# 3   AN (Atlantic North)           0         0             0.01         0.00
# 4         AR (Arkansas)           2        32           313.81         1.41
# ..                  ...         ...       ...              ...          ...
# 62         VT (Vermont)           0         0             1.91         0.01
# 63      WA (Washington)           5        11          1340.16         0.52
# 64       WI (Wisconsin)          11         1            79.28         0.26
# 65   WV (West Virginia)           1         3             5.62         0.00
# 66         WY (Wyoming)           0         0             0.03         0.00
#
#     total_damage
# 0          35.85
# 1         315.47
# 2           0.00
# 3           0.01
# 4         315.21
# ..           ...
# 62          1.92
# 63       1340.68
# 64         79.54
# 65          5.62
# 66          0.03
#
# [67 rows x 6 columns]

# %%
disaster2016 = pd.read_csv('datasets/nat_disast_bystate_deaths_cost/state16.csv')
disaster2016
# Out:
#    2016 Summary of Hazardous Weather Fatalities, Injuries, and Damage Costs by State  \
# 0                                               State
# 1                                                 NaN
# 2                                                 NaN
# 3                                         AK (Alaska)
# 4                                        AL (Alabama)
# ..                                                ...
# 68                                     WI (Wisconsin)
# 69                                 WV (West Virginia)
# 70                                       WY (Wyoming)
# 71                                              Total
# 72            Report generated: 5/11/2017 10:46:03 AM
#
#     Unnamed: 1 Unnamed: 2   Unnamed: 3   Unnamed: 4   Unnamed: 5
# 0   Fatalities   Injuries     Property         Crop        Total
# 1          NaN        NaN       Damage       Damage       Damage
# 2          NaN        NaN  (million $)  (million $)  (million $)
# 3            4          2          0.2            0          0.2
# 4            7         32         4.31            0         4.31
# ..         ...        ...          ...          ...          ...
# 68          20         33        37.28         0.67        37.95
# 69          24         12       172.54            0       172.54
# 70           6          4          3.1            0          3.1
# 71         458       1276      18194.7       243.29        18438
# 72         NaN        NaN          NaN          NaN        6 / 6
#
# [73 rows x 6 columns]

# %%
disaster2016.columns
# Out:
# Index(['2016 Summary of Hazardous Weather Fatalities, Injuries, and Damage Costs by State',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5'],
#       dtype='object')

# %%
# rename columns
disaster2016.columns = ['state', 'fatalities', 'injuries', 'property_damage', 'crop_damage',
                       'total_damage']
disaster2016.columns
# Out:
# Index(['state', 'fatalities', 'injuries', 'property_damage', 'crop_damage',
#        'total_damage'],
#       dtype='object')

# %%
disaster2016
# Out:
#                                       state  fatalities  injuries  \
# 0                                     State  Fatalities  Injuries
# 1                                       NaN         NaN       NaN
# 2                                       NaN         NaN       NaN
# 3                               AK (Alaska)           4         2
# 4                              AL (Alabama)           7        32
# ..                                      ...         ...       ...
# 68                           WI (Wisconsin)          20        33
# 69                       WV (West Virginia)          24        12
# 70                             WY (Wyoming)           6         4
# 71                                    Total         458      1276
# 72  Report generated: 5/11/2017 10:46:03 AM         NaN       NaN
#
#    property_damage  crop_damage total_damage
# 0         Property         Crop        Total
# 1           Damage       Damage       Damage
# 2      (million $)  (million $)  (million $)
# 3              0.2            0          0.2
# 4             4.31            0         4.31
# ..             ...          ...          ...
# 68           37.28         0.67        37.95
# 69          172.54            0       172.54
# 70             3.1            0          3.1
# 71         18194.7       243.29        18438
# 72             NaN          NaN        6 / 6
#
# [73 rows x 6 columns]

# %%
# delete first three rows and last two rows of original dataframe
disaster2016 = disaster2016.drop(labels= [0, 1, 2, 71, 72])
disaster2016
# Out:
#                   state fatalities injuries property_damage crop_damage  \
# 3           AK (Alaska)          4        2             0.2           0
# 4          AL (Alabama)          7       32            4.31           0
# 5   AM (Atlantic South)          4        2               0           0
# 6   AN (Atlantic North)          0        0               0           0
# 7         AR (Arkansas)          2        8           13.38         0.2
# ..                  ...        ...      ...             ...         ...
# 66         VT (Vermont)          1        0            3.94           0
# 67      WA (Washington)          5        6            8.43           0
# 68       WI (Wisconsin)         20       33           37.28        0.67
# 69   WV (West Virginia)         24       12          172.54           0
# 70         WY (Wyoming)          6        4             3.1           0
#
#    total_damage
# 3           0.2
# 4          4.31
# 5             0
# 6             0
# 7         13.58
# ..          ...
# 66         3.94
# 67         8.43
# 68        37.95
# 69       172.54
# 70          3.1
#
# [68 rows x 6 columns]

# %%
disaster2016 = disaster2016.reset_index(drop= True)
disaster2016
# Out:
#                   state fatalities injuries property_damage crop_damage  \
# 0           AK (Alaska)          4        2             0.2           0
# 1          AL (Alabama)          7       32            4.31           0
# 2   AM (Atlantic South)          4        2               0           0
# 3   AN (Atlantic North)          0        0               0           0
# 4         AR (Arkansas)          2        8           13.38         0.2
# ..                  ...        ...      ...             ...         ...
# 63         VT (Vermont)          1        0            3.94           0
# 64      WA (Washington)          5        6            8.43           0
# 65       WI (Wisconsin)         20       33           37.28        0.67
# 66   WV (West Virginia)         24       12          172.54           0
# 67         WY (Wyoming)          6        4             3.1           0
#
#    total_damage
# 0           0.2
# 1          4.31
# 2             0
# 3             0
# 4         13.58
# ..          ...
# 63         3.94
# 64         8.43
# 65        37.95
# 66       172.54
# 67          3.1
#
# [68 rows x 6 columns]

# %%
# check for missing values
disaster2016.isna().sum()
# Out:
# state              0
# fatalities         1
# injuries           1
# property_damage    1
# crop_damage        1
# total_damage       0
# dtype: int64

# %%
# find rows that have missing values
disaster2016[disaster2016.isnull().any(axis=1)]
# Out:
#                                       state fatalities injuries  \
# 39  Report generated: 5/11/2017 10:46:03 AM        NaN      NaN
#
#    property_damage crop_damage total_damage
# 39             NaN         NaN        5 / 6

# %%
disaster2016 = disaster2016.drop(39)
disaster2016
# Out:
#                   state fatalities injuries property_damage crop_damage  \
# 0           AK (Alaska)          4        2             0.2           0
# 1          AL (Alabama)          7       32            4.31           0
# 2   AM (Atlantic South)          4        2               0           0
# 3   AN (Atlantic North)          0        0               0           0
# 4         AR (Arkansas)          2        8           13.38         0.2
# ..                  ...        ...      ...             ...         ...
# 63         VT (Vermont)          1        0            3.94           0
# 64      WA (Washington)          5        6            8.43           0
# 65       WI (Wisconsin)         20       33           37.28        0.67
# 66   WV (West Virginia)         24       12          172.54           0
# 67         WY (Wyoming)          6        4             3.1           0
#
#    total_damage
# 0           0.2
# 1          4.31
# 2             0
# 3             0
# 4         13.58
# ..          ...
# 63         3.94
# 64         8.43
# 65        37.95
# 66       172.54
# 67          3.1
#
# [67 rows x 6 columns]

# %%
disaster2016.isna().sum()
# Out:
# state              0
# fatalities         0
# injuries           0
# property_damage    0
# crop_damage        0
# total_damage       0
# dtype: int64

# %%
disaster2016.dtypes
# Out:
# state              object
# fatalities         object
# injuries           object
# property_damage    object
# crop_damage        object
# total_damage       object
# dtype: object

# %%
# convert columns to correct data types
disaster2016[['fatalities','injuries', 'property_damage','crop_damage', 'total_damage']] = disaster2016[['fatalities','injuries', 'property_damage','crop_damage', 'total_damage']].apply(pd.to_numeric)
disaster2016.dtypes
# Out:
# state               object
# fatalities           int64
# injuries             int64
# property_damage    float64
# crop_damage        float64
# total_damage       float64
# dtype: object

# %%
disaster2016
# Out:
#                   state  fatalities  injuries  property_damage  crop_damage  \
# 0           AK (Alaska)           4         2             0.20         0.00
# 1          AL (Alabama)           7        32             4.31         0.00
# 2   AM (Atlantic South)           4         2             0.00         0.00
# 3   AN (Atlantic North)           0         0             0.00         0.00
# 4         AR (Arkansas)           2         8            13.38         0.20
# ..                  ...         ...       ...              ...          ...
# 63         VT (Vermont)           1         0             3.94         0.00
# 64      WA (Washington)           5         6             8.43         0.00
# 65       WI (Wisconsin)          20        33            37.28         0.67
# 66   WV (West Virginia)          24        12           172.54         0.00
# 67         WY (Wyoming)           6         4             3.10         0.00
#
#     total_damage
# 0           0.20
# 1           4.31
# 2           0.00
# 3           0.00
# 4          13.58
# ..           ...
# 63          3.94
# 64          8.43
# 65         37.95
# 66        172.54
# 67          3.10
#
# [67 rows x 6 columns]

# %%
len(disaster2016['state'].unique())
# Out:
# 67

# %%
disaster2016['state'].unique()
# Out:
# array(['AK (Alaska)', 'AL (Alabama)', 'AM (Atlantic South)',
#        'AN (Atlantic North)', 'AR (Arkansas)', 'AS (American Samoa)',
#        'AZ (Arizona)', 'CA (California)', 'CO (Colorado)',
#        'CT (Connecticut)', 'DC (District of Columbia)', 'DE (Delaware)',
#        'FL (Florida)', 'GA (Georgia)', 'GM (Gulf of Mexico)', 'GU (Guam)',
#        'HI (Hawaii)', 'IA (Iowa)', 'ID (Idaho)', 'IL (Illinois)',
#        'IN (Indiana)', 'KS (Kansas)', 'KY (Kentucky)', 'LA (Louisiana)',
#        'LC (Lake St.Clair)', 'LE (Lake Erie)', 'LH (Lake Huron)',
#        'LM (Lake Michigan)', 'LO (Lake Ontario)', 'LS (Lake Superior)',
#        'MA (Massachusetts)', 'MD (Maryland)', 'ME (Maine)',
#        'MI (Michigan)', 'MN (Minnesota)', 'MO (Missouri)',
#        'MS (Mississippi)', 'MT (Montana)', 'NC (North Carolina)',
#        'ND (North Dakota)', 'NE (Nebraska)', 'NH (New Hampshire)',
#        'NJ (New Jersey)', 'NM (New Mexico)', 'NV (Nevada)',
#        'NY (New York)', 'OH (Ohio)', 'OK (Oklahoma)', 'OR (Oregon)',
#        'PA (Pennsylvania)', 'PH (Hawaii Waters)', 'PR (Puerto Rico)',
#        'PZ (East Pacific)', 'RI (Rhode Island)', 'SC (South Carolina)',
#        'SD (South Dakota)', 'SL (St.Lawrence River)', 'TN (Tennessee)',
#        'TX (Texas)', 'UT (Utah)', 'VA (Virginia)', 'VI (Virgin Islands)',
#        'VT (Vermont)', 'WA (Washington)', 'WI (Wisconsin)',
#        'WV (West Virginia)', 'WY (Wyoming)'], dtype=object)

# %%
disaster2017 = pd.read_csv('datasets/nat_disast_bystate_deaths_cost/state17.csv')
disaster2017
# Out:
#    2017 Summary of Hazardous Weather Fatalities, Injuries, and Damage Costs by State  \
# 0                                               State
# 1                                                 NaN
# 2                                                 NaN
# 3                                         AK (Alaska)
# 4                                        AL (Alabama)
# ..                                                ...
# 68                                     WI (Wisconsin)
# 69                                 WV (West Virginia)
# 70                                       WY (Wyoming)
# 71                                              Total
# 72             Report generated: 4/25/2018 3:36:29 PM
#
#     Unnamed: 1 Unnamed: 2   Unnamed: 3   Unnamed: 4   Unnamed: 5
# 0   Fatalities   Injuries     Property         Crop        Total
# 1          NaN        NaN       Damage       Damage       Damage
# 2          NaN        NaN  (million $)  (million $)  (million $)
# 3            2          0         6.53            0         6.53
# 4           14         35        31.59            0        31.59
# ..         ...        ...          ...          ...          ...
# 68          10         29        82.84        41.43       124.27
# 69           2          2         6.88            0         6.88
# 70           1          1            3            0            3
# 71         508       1205      87377.5      1913.21     89290.72
# 72         NaN        NaN          NaN          NaN        6 / 6
#
# [73 rows x 6 columns]

# %%
# rename columns
disaster2017.columns = ['state', 'fatalities', 'injuries', 'property_damage', 'crop_damage',
                       'total_damage']
disaster2017.columns
# Out:
# Index(['state', 'fatalities', 'injuries', 'property_damage', 'crop_damage',
#        'total_damage'],
#       dtype='object')

# %%
disaster2017
# Out:
#                                      state  fatalities  injuries  \
# 0                                    State  Fatalities  Injuries
# 1                                      NaN         NaN       NaN
# 2                                      NaN         NaN       NaN
# 3                              AK (Alaska)           2         0
# 4                             AL (Alabama)          14        35
# ..                                     ...         ...       ...
# 68                          WI (Wisconsin)          10        29
# 69                      WV (West Virginia)           2         2
# 70                            WY (Wyoming)           1         1
# 71                                   Total         508      1205
# 72  Report generated: 4/25/2018 3:36:29 PM         NaN       NaN
#
#    property_damage  crop_damage total_damage
# 0         Property         Crop        Total
# 1           Damage       Damage       Damage
# 2      (million $)  (million $)  (million $)
# 3             6.53            0         6.53
# 4            31.59            0        31.59
# ..             ...          ...          ...
# 68           82.84        41.43       124.27
# 69            6.88            0         6.88
# 70               3            0            3
# 71         87377.5      1913.21     89290.72
# 72             NaN          NaN        6 / 6
#
# [73 rows x 6 columns]

# %%
# delete first three rows and last two rows of original dataframe
disaster2017 = disaster2017.drop(labels= [0, 1, 2, 71, 72])
disaster2017
# Out:
#                   state fatalities injuries property_damage crop_damage  \
# 3           AK (Alaska)          2        0            6.53           0
# 4          AL (Alabama)         14       35           31.59           0
# 5   AM (Atlantic South)          3        0               0           0
# 6   AN (Atlantic North)          1        0            0.01           0
# 7         AR (Arkansas)          9       17           37.58       23.51
# ..                  ...        ...      ...             ...         ...
# 66         VT (Vermont)          0        1           14.53        0.11
# 67      WA (Washington)          1        7           82.47           0
# 68       WI (Wisconsin)         10       29           82.84       41.43
# 69   WV (West Virginia)          2        2            6.88           0
# 70         WY (Wyoming)          1        1               3           0
#
#    total_damage
# 3          6.53
# 4         31.59
# 5             0
# 6          0.01
# 7         61.09
# ..          ...
# 66        14.64
# 67        82.47
# 68       124.27
# 69         6.88
# 70            3
#
# [68 rows x 6 columns]

# %%
disaster2017 = disaster2017.reset_index(drop= True)
disaster2017
# Out:
#                   state fatalities injuries property_damage crop_damage  \
# 0           AK (Alaska)          2        0            6.53           0
# 1          AL (Alabama)         14       35           31.59           0
# 2   AM (Atlantic South)          3        0               0           0
# 3   AN (Atlantic North)          1        0            0.01           0
# 4         AR (Arkansas)          9       17           37.58       23.51
# ..                  ...        ...      ...             ...         ...
# 63         VT (Vermont)          0        1           14.53        0.11
# 64      WA (Washington)          1        7           82.47           0
# 65       WI (Wisconsin)         10       29           82.84       41.43
# 66   WV (West Virginia)          2        2            6.88           0
# 67         WY (Wyoming)          1        1               3           0
#
#    total_damage
# 0          6.53
# 1         31.59
# 2             0
# 3          0.01
# 4         61.09
# ..          ...
# 63        14.64
# 64        82.47
# 65       124.27
# 66         6.88
# 67            3
#
# [68 rows x 6 columns]

# %%
# check for missing values
disaster2017.isna().sum()
# Out:
# state              0
# fatalities         1
# injuries           1
# property_damage    1
# crop_damage        1
# total_damage       0
# dtype: int64

# %%
# find rows that have missing values
disaster2017[disaster2017.isnull().any(axis=1)]
# Out:
#                                      state fatalities injuries  \
# 39  Report generated: 4/25/2018 3:36:29 PM        NaN      NaN
#
#    property_damage crop_damage total_damage
# 39             NaN         NaN        5 / 6

# %%
disaster2017 = disaster2017.drop(39)
disaster2017
# Out:
#                   state fatalities injuries property_damage crop_damage  \
# 0           AK (Alaska)          2        0            6.53           0
# 1          AL (Alabama)         14       35           31.59           0
# 2   AM (Atlantic South)          3        0               0           0
# 3   AN (Atlantic North)          1        0            0.01           0
# 4         AR (Arkansas)          9       17           37.58       23.51
# ..                  ...        ...      ...             ...         ...
# 63         VT (Vermont)          0        1           14.53        0.11
# 64      WA (Washington)          1        7           82.47           0
# 65       WI (Wisconsin)         10       29           82.84       41.43
# 66   WV (West Virginia)          2        2            6.88           0
# 67         WY (Wyoming)          1        1               3           0
#
#    total_damage
# 0          6.53
# 1         31.59
# 2             0
# 3          0.01
# 4         61.09
# ..          ...
# 63        14.64
# 64        82.47
# 65       124.27
# 66         6.88
# 67            3
#
# [67 rows x 6 columns]

# %%
disaster2017.isna().sum()
# Out:
# state              0
# fatalities         0
# injuries           0
# property_damage    0
# crop_damage        0
# total_damage       0
# dtype: int64

# %%
disaster2017.dtypes
# Out:
# state              object
# fatalities         object
# injuries           object
# property_damage    object
# crop_damage        object
# total_damage       object
# dtype: object

# %%
# convert columns to correct data types
disaster2017[['fatalities','injuries', 'property_damage','crop_damage', 'total_damage']] = disaster2017[['fatalities','injuries', 'property_damage','crop_damage', 'total_damage']].apply(pd.to_numeric)
disaster2017.dtypes
# Out:
# state               object
# fatalities           int64
# injuries             int64
# property_damage    float64
# crop_damage        float64
# total_damage       float64
# dtype: object

# %%
disaster2017
# Out:
#                   state  fatalities  injuries  property_damage  crop_damage  \
# 0           AK (Alaska)           2         0             6.53         0.00
# 1          AL (Alabama)          14        35            31.59         0.00
# 2   AM (Atlantic South)           3         0             0.00         0.00
# 3   AN (Atlantic North)           1         0             0.01         0.00
# 4         AR (Arkansas)           9        17            37.58        23.51
# ..                  ...         ...       ...              ...          ...
# 63         VT (Vermont)           0         1            14.53         0.11
# 64      WA (Washington)           1         7            82.47         0.00
# 65       WI (Wisconsin)          10        29            82.84        41.43
# 66   WV (West Virginia)           2         2             6.88         0.00
# 67         WY (Wyoming)           1         1             3.00         0.00
#
#     total_damage
# 0           6.53
# 1          31.59
# 2           0.00
# 3           0.01
# 4          61.09
# ..           ...
# 63         14.64
# 64         82.47
# 65        124.27
# 66          6.88
# 67          3.00
#
# [67 rows x 6 columns]

# %%
disaster2018 = pd.read_csv('datasets/nat_disast_bystate_deaths_cost/state18.csv')
disaster2018
# Out:
#    2018 Summary of Hazardous Weather Fatalities, Injuries, and Damage Costs by State  \
# 0                                               State
# 1                                                 NaN
# 2                                                 NaN
# 3                                         AK (Alaska)
# 4                                        AL (Alabama)
# ..                                                ...
# 68                                     WI (Wisconsin)
# 69                                 WV (West Virginia)
# 70                                       WY (Wyoming)
# 71                                              Total
# 72            Report generated: 4/29/2019 11:31:38 AM
#
#     Unnamed: 1 Unnamed: 2   Unnamed: 3   Unnamed: 4   Unnamed: 5
# 0   Fatalities   Injuries     Property         Crop        Total
# 1          NaN        NaN       Damage       Damage       Damage
# 2          NaN        NaN  (million $)  (million $)  (million $)
# 3            0          0         3.89            0         3.89
# 4            6         35         8.34            0         8.34
# ..         ...        ...          ...          ...          ...
# 68          12         11       181.95         4.22       186.17
# 69           3          0         6.73            0         6.74
# 70           2          5         10.2            0         10.2
# 71         530       1378     35849.32      5102.54     40951.86
# 72         NaN        NaN          NaN          NaN        6 / 6
#
# [73 rows x 6 columns]

# %%
# rename columns
disaster2018.columns = ['state', 'fatalities', 'injuries', 'property_damage', 'crop_damage',
                       'total_damage']
disaster2018.columns
# Out:
# Index(['state', 'fatalities', 'injuries', 'property_damage', 'crop_damage',
#        'total_damage'],
#       dtype='object')

# %%
disaster2018
# Out:
#                                       state  fatalities  injuries  \
# 0                                     State  Fatalities  Injuries
# 1                                       NaN         NaN       NaN
# 2                                       NaN         NaN       NaN
# 3                               AK (Alaska)           0         0
# 4                              AL (Alabama)           6        35
# ..                                      ...         ...       ...
# 68                           WI (Wisconsin)          12        11
# 69                       WV (West Virginia)           3         0
# 70                             WY (Wyoming)           2         5
# 71                                    Total         530      1378
# 72  Report generated: 4/29/2019 11:31:38 AM         NaN       NaN
#
#    property_damage  crop_damage total_damage
# 0         Property         Crop        Total
# 1           Damage       Damage       Damage
# 2      (million $)  (million $)  (million $)
# 3             3.89            0         3.89
# 4             8.34            0         8.34
# ..             ...          ...          ...
# 68          181.95         4.22       186.17
# 69            6.73            0         6.74
# 70            10.2            0         10.2
# 71        35849.32      5102.54     40951.86
# 72             NaN          NaN        6 / 6
#
# [73 rows x 6 columns]

# %%
# delete first three rows and last two rows of original dataframe
disaster2018 = disaster2018.drop(labels= [0, 1, 2, 71, 72])
disaster2018
# Out:
#                   state fatalities injuries property_damage crop_damage  \
# 3           AK (Alaska)          0        0            3.89           0
# 4          AL (Alabama)          6       35            8.34           0
# 5   AM (Atlantic South)          0        0               0           0
# 6   AN (Atlantic North)          2        2               0           0
# 7         AR (Arkansas)          3       12           19.82        0.04
# ..                  ...        ...      ...             ...         ...
# 66         VT (Vermont)          1        0            5.05           0
# 67      WA (Washington)          2        0          141.83           0
# 68       WI (Wisconsin)         12       11          181.95        4.22
# 69   WV (West Virginia)          3        0            6.73           0
# 70         WY (Wyoming)          2        5            10.2           0
#
#    total_damage
# 3          3.89
# 4          8.34
# 5             0
# 6             0
# 7         19.86
# ..          ...
# 66         5.05
# 67       141.83
# 68       186.17
# 69         6.74
# 70         10.2
#
# [68 rows x 6 columns]

# %%
disaster2018 = disaster2018.reset_index(drop= True)
disaster2018
# Out:
#                   state fatalities injuries property_damage crop_damage  \
# 0           AK (Alaska)          0        0            3.89           0
# 1          AL (Alabama)          6       35            8.34           0
# 2   AM (Atlantic South)          0        0               0           0
# 3   AN (Atlantic North)          2        2               0           0
# 4         AR (Arkansas)          3       12           19.82        0.04
# ..                  ...        ...      ...             ...         ...
# 63         VT (Vermont)          1        0            5.05           0
# 64      WA (Washington)          2        0          141.83           0
# 65       WI (Wisconsin)         12       11          181.95        4.22
# 66   WV (West Virginia)          3        0            6.73           0
# 67         WY (Wyoming)          2        5            10.2           0
#
#    total_damage
# 0          3.89
# 1          8.34
# 2             0
# 3             0
# 4         19.86
# ..          ...
# 63         5.05
# 64       141.83
# 65       186.17
# 66         6.74
# 67         10.2
#
# [68 rows x 6 columns]

# %%
# find rows that have missing values
disaster2018[disaster2018.isnull().any(axis=1)]
# Out:
#                                       state fatalities injuries  \
# 39  Report generated: 4/29/2019 11:31:38 AM        NaN      NaN
#
#    property_damage crop_damage total_damage
# 39             NaN         NaN        5 / 6

# %%
disaster2018 = disaster2018.drop(39)
disaster2018
# Out:
#                   state fatalities injuries property_damage crop_damage  \
# 0           AK (Alaska)          0        0            3.89           0
# 1          AL (Alabama)          6       35            8.34           0
# 2   AM (Atlantic South)          0        0               0           0
# 3   AN (Atlantic North)          2        2               0           0
# 4         AR (Arkansas)          3       12           19.82        0.04
# ..                  ...        ...      ...             ...         ...
# 63         VT (Vermont)          1        0            5.05           0
# 64      WA (Washington)          2        0          141.83           0
# 65       WI (Wisconsin)         12       11          181.95        4.22
# 66   WV (West Virginia)          3        0            6.73           0
# 67         WY (Wyoming)          2        5            10.2           0
#
#    total_damage
# 0          3.89
# 1          8.34
# 2             0
# 3             0
# 4         19.86
# ..          ...
# 63         5.05
# 64       141.83
# 65       186.17
# 66         6.74
# 67         10.2
#
# [67 rows x 6 columns]

# %%
disaster2018.isna().sum()
# Out:
# state              0
# fatalities         0
# injuries           0
# property_damage    0
# crop_damage        0
# total_damage       0
# dtype: int64

# %%
disaster2018.dtypes
# Out:
# state              object
# fatalities         object
# injuries           object
# property_damage    object
# crop_damage        object
# total_damage       object
# dtype: object

# %%
# convert columns to correct data types
disaster2018[['fatalities','injuries', 'property_damage','crop_damage', 'total_damage']] = disaster2018[['fatalities','injuries', 'property_damage','crop_damage', 'total_damage']].apply(pd.to_numeric)
disaster2018.dtypes
# Out:
# state               object
# fatalities           int64
# injuries             int64
# property_damage    float64
# crop_damage        float64
# total_damage       float64
# dtype: object

# %%
disaster2018
# Out:
#                   state  fatalities  injuries  property_damage  crop_damage  \
# 0           AK (Alaska)           0         0             3.89         0.00
# 1          AL (Alabama)           6        35             8.34         0.00
# 2   AM (Atlantic South)           0         0             0.00         0.00
# 3   AN (Atlantic North)           2         2             0.00         0.00
# 4         AR (Arkansas)           3        12            19.82         0.04
# ..                  ...         ...       ...              ...          ...
# 63         VT (Vermont)           1         0             5.05         0.00
# 64      WA (Washington)           2         0           141.83         0.00
# 65       WI (Wisconsin)          12        11           181.95         4.22
# 66   WV (West Virginia)           3         0             6.73         0.00
# 67         WY (Wyoming)           2         5            10.20         0.00
#
#     total_damage
# 0           3.89
# 1           8.34
# 2           0.00
# 3           0.00
# 4          19.86
# ..           ...
# 63          5.05
# 64        141.83
# 65        186.17
# 66          6.74
# 67         10.20
#
# [67 rows x 6 columns]

# %%
disaster2019 = pd.read_csv('datasets/nat_disast_bystate_deaths_cost/state19.csv')
disaster2019
# Out:
#    2019 Summary of Hazardous Weather Fatalities, Injuries, and Damage Costs by State  \
# 0                                               State
# 1                                                 NaN
# 2                                                 NaN
# 3                                         AK (Alaska)
# 4                                        AL (Alabama)
# ..                                                ...
# 66                                     WI (Wisconsin)
# 67                                 WV (West Virginia)
# 68                                       WY (Wyoming)
# 69                                              Total
# 70             Report generated: 9/21/2021 8:26:24 AM
#
#     Unnamed: 1 Unnamed: 2   Unnamed: 3   Unnamed: 4   Unnamed: 5
# 0   Fatalities   Injuries     Property         Crop        Total
# 1          NaN        NaN       Damage       Damage       Damage
# 2          NaN        NaN  (million $)  (million $)  (million $)
# 3            0          0         8.55            0         8.55
# 4           31        109         0.98            0         0.98
# ..         ...        ...          ...          ...          ...
# 66          10         56        20.71         0.99         21.7
# 67           2          3         8.28            3        11.28
# 68           3          1         1.33            0         1.33
# 69         534       1239      6251.83      1405.19      7657.01
# 70         NaN        NaN          NaN          NaN        6 / 6
#
# [71 rows x 6 columns]

# %%
# rename columns
disaster2019.columns = ['state', 'fatalities', 'injuries', 'property_damage', 'crop_damage',
                       'total_damage']
disaster2019.columns
# Out:
# Index(['state', 'fatalities', 'injuries', 'property_damage', 'crop_damage',
#        'total_damage'],
#       dtype='object')

# %%
disaster2019
# Out:
#                                      state  fatalities  injuries  \
# 0                                    State  Fatalities  Injuries
# 1                                      NaN         NaN       NaN
# 2                                      NaN         NaN       NaN
# 3                              AK (Alaska)           0         0
# 4                             AL (Alabama)          31       109
# ..                                     ...         ...       ...
# 66                          WI (Wisconsin)          10        56
# 67                      WV (West Virginia)           2         3
# 68                            WY (Wyoming)           3         1
# 69                                   Total         534      1239
# 70  Report generated: 9/21/2021 8:26:24 AM         NaN       NaN
#
#    property_damage  crop_damage total_damage
# 0         Property         Crop        Total
# 1           Damage       Damage       Damage
# 2      (million $)  (million $)  (million $)
# 3             8.55            0         8.55
# 4             0.98            0         0.98
# ..             ...          ...          ...
# 66           20.71         0.99         21.7
# 67            8.28            3        11.28
# 68            1.33            0         1.33
# 69         6251.83      1405.19      7657.01
# 70             NaN          NaN        6 / 6
#
# [71 rows x 6 columns]

# %%
# delete first three rows and last two rows of original dataframe
disaster2019 = disaster2019.drop(labels= [0, 1, 2, 69, 70])
disaster2019
# Out:
#                   state fatalities injuries property_damage crop_damage  \
# 3           AK (Alaska)          0        0            8.55           0
# 4          AL (Alabama)         31      109            0.98           0
# 5   AM (Atlantic South)          2        0               0           0
# 6   AN (Atlantic North)          1        0            0.11           0
# 7         AR (Arkansas)          6       22           24.94        4.18
# ..                  ...        ...      ...             ...         ...
# 64         VT (Vermont)          2        0            9.24           0
# 65      WA (Washington)          1       17            4.96           0
# 66       WI (Wisconsin)         10       56           20.71        0.99
# 67   WV (West Virginia)          2        3            8.28           3
# 68         WY (Wyoming)          3        1            1.33           0
#
#    total_damage
# 3          8.55
# 4          0.98
# 5             0
# 6          0.11
# 7         29.12
# ..          ...
# 64         9.24
# 65         4.96
# 66         21.7
# 67        11.28
# 68         1.33
#
# [66 rows x 6 columns]

# %%
disaster2019 = disaster2019.reset_index(drop= True)
disaster2019
# Out:
#                   state fatalities injuries property_damage crop_damage  \
# 0           AK (Alaska)          0        0            8.55           0
# 1          AL (Alabama)         31      109            0.98           0
# 2   AM (Atlantic South)          2        0               0           0
# 3   AN (Atlantic North)          1        0            0.11           0
# 4         AR (Arkansas)          6       22           24.94        4.18
# ..                  ...        ...      ...             ...         ...
# 61         VT (Vermont)          2        0            9.24           0
# 62      WA (Washington)          1       17            4.96           0
# 63       WI (Wisconsin)         10       56           20.71        0.99
# 64   WV (West Virginia)          2        3            8.28           3
# 65         WY (Wyoming)          3        1            1.33           0
#
#    total_damage
# 0          8.55
# 1          0.98
# 2             0
# 3          0.11
# 4         29.12
# ..          ...
# 61         9.24
# 62         4.96
# 63         21.7
# 64        11.28
# 65         1.33
#
# [66 rows x 6 columns]

# %%
# find rows that have missing values
disaster2019[disaster2019.isnull().any(axis=1)]
# Out:
#                                      state fatalities injuries  \
# 39  Report generated: 9/21/2021 8:26:24 AM        NaN      NaN
#
#    property_damage crop_damage total_damage
# 39             NaN         NaN        5 / 6

# %%
disaster2019 = disaster2019.drop(39)
disaster2019
# Out:
#                   state fatalities injuries property_damage crop_damage  \
# 0           AK (Alaska)          0        0            8.55           0
# 1          AL (Alabama)         31      109            0.98           0
# 2   AM (Atlantic South)          2        0               0           0
# 3   AN (Atlantic North)          1        0            0.11           0
# 4         AR (Arkansas)          6       22           24.94        4.18
# ..                  ...        ...      ...             ...         ...
# 61         VT (Vermont)          2        0            9.24           0
# 62      WA (Washington)          1       17            4.96           0
# 63       WI (Wisconsin)         10       56           20.71        0.99
# 64   WV (West Virginia)          2        3            8.28           3
# 65         WY (Wyoming)          3        1            1.33           0
#
#    total_damage
# 0          8.55
# 1          0.98
# 2             0
# 3          0.11
# 4         29.12
# ..          ...
# 61         9.24
# 62         4.96
# 63         21.7
# 64        11.28
# 65         1.33
#
# [65 rows x 6 columns]

# %%
disaster2019.isna().sum()
# Out:
# state              0
# fatalities         0
# injuries           0
# property_damage    0
# crop_damage        0
# total_damage       0
# dtype: int64

# %%
disaster2019.dtypes
# Out:
# state              object
# fatalities         object
# injuries           object
# property_damage    object
# crop_damage        object
# total_damage       object
# dtype: object

# %%
# convert columns to correct data types
disaster2019[['fatalities','injuries', 'property_damage','crop_damage', 'total_damage']] = disaster2019[['fatalities','injuries', 'property_damage','crop_damage', 'total_damage']].apply(pd.to_numeric)
disaster2019.dtypes
# Out:
# state               object
# fatalities           int64
# injuries             int64
# property_damage    float64
# crop_damage        float64
# total_damage       float64
# dtype: object

# %%
disaster2019
# Out:
#                   state  fatalities  injuries  property_damage  crop_damage  \
# 0           AK (Alaska)           0         0             8.55         0.00
# 1          AL (Alabama)          31       109             0.98         0.00
# 2   AM (Atlantic South)           2         0             0.00         0.00
# 3   AN (Atlantic North)           1         0             0.11         0.00
# 4         AR (Arkansas)           6        22            24.94         4.18
# ..                  ...         ...       ...              ...          ...
# 61         VT (Vermont)           2         0             9.24         0.00
# 62      WA (Washington)           1        17             4.96         0.00
# 63       WI (Wisconsin)          10        56            20.71         0.99
# 64   WV (West Virginia)           2         3             8.28         3.00
# 65         WY (Wyoming)           3         1             1.33         0.00
#
#     total_damage
# 0           8.55
# 1           0.98
# 2           0.00
# 3           0.11
# 4          29.12
# ..           ...
# 61          9.24
# 62          4.96
# 63         21.70
# 64         11.28
# 65          1.33
#
# [65 rows x 6 columns]

# %% [markdown]
# # Data Analysis & Results (EDA)

# %% [markdown]
# Carry out EDA on your dataset(s); Describe in this section

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION
