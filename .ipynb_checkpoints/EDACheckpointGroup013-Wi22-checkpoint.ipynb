# %% [markdown]
# # COGS 108 - EDA Checkpoint

# %% [markdown]
# # Names
#
# - Tyler Le
# - Aditya Tomar
# - William Lynch
# - Michael Mao
# - Natalie Quach

# %% [markdown]
# <a id='research_question'></a>
# # Research Question

# %% [markdown]
# Is there a positive correlation between the cost of living and the impact of natural disasters in terms of injuries, casualties, and property damage per capita at the county level? Furthermore, in which state does the impact of natural disasters affect cost of living the most?

# %% [markdown]
# # Setup

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import boxcox
# for choropleth
import plotly.express as px

# used for choropleth
from urllib.request import urlopen
import json

# filter extra noise from warnings
import warnings
warnings.filterwarnings('ignore')

# Statmodels & patsy
import patsy
import statsmodels.api as sm

# Make plots just slightly bigger for displaying well in notebook
plt.rcParams['figure.figsize'] = (10, 5)

# Displaying figures as image
from IPython.display import Image

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Describe your data cleaning steps here.

# %%
nri = pd.read_csv('datasets/cleaned/nri.csv') # using previously cleaned dataset
col = pd.read_csv('datasets/cleaned/col_updated.csv')
col['county'] = col['county'].str.replace(' County','')
col = col.rename(columns={'State':'state_abbrv'})
df = pd.merge(col,nri,how = 'inner', on = ['state_abbrv','county'])
df
# Out:
#            City state_abbrv  Cost of Living Index      city_state  \
# 0       Abilene          TX                  89.1     Abilene, TX
# 1        Adrian          MI                  90.5      Adrian, MI
# 2         Akron          OH                  89.4       Akron, OH
# 3    Alamogordo          NM                  85.8  Alamogordo, NM
# 4        Albany          GA                  87.3      Albany, GA
# ..          ...         ...                   ...             ...
# 461    Wheeling          WV                  84.1    Wheeling, WV
# 462  New London          CT                 105.9  New London, CT
# 463      Daphne          AL                  96.6      Daphne, AL
# 464    Victoria          TX                  89.5    Victoria, TX
# 465    Aberdeen          WA                  97.6    Aberdeen, WA
#
#                                                geocode        county  \
# 0    Abilene, Taylor County, Texas, 79697, United S...        Taylor
# ...

# %% [markdown]
# # Data Analysis & Results (EDA)

# %% [markdown]
# Carry out EDA on your dataset(s); Describe in this section

# %%
fig, (ax1,ax2) = plt.subplots(1,2, figsize=(20,8))
sns.histplot(x = 'risk_score', ax = ax1, data = df)
sns.histplot(x = 'Cost of Living Index', ax = ax2, data = df)

ax1.set_title('Risk Score Distribution')
ax2.set_title('Cost of Living Index Distribution')
sns.despine()
plt.show()

# %%
df['risk_score'].describe()
# Out:
# count    466.000000
# mean      16.913272
# std       10.204795
# min        4.018956
# 25%       10.239813
# 50%       14.434611
# 75%       20.239352
# max      100.000000
# Name: risk_score, dtype: float64

# %%
df['Cost of Living Index'].describe()
# Out:
# count    466.000000
# mean      95.815880
# std       11.914475
# min       80.000000
# 25%       88.200000
# 50%       91.700000
# 75%      100.100000
# max      163.900000
# Name: Cost of Living Index, dtype: float64

# %% [markdown]
# **Both distributions for Cost of Living Index and risk_score are both skewed to the right, to make our data as 'normal' as possible we can apply a log-transformation to our data**

# %%
fig, (ax1,ax2) = plt.subplots(1,2, figsize=(20,8))
transformed_risk_score, risk_score_lambda = boxcox(df['risk_score'])
transformed_col_index, col_index_lambda = boxcox(df['Cost of Living Index'])

sns.histplot(x = transformed_risk_score,ax=ax1,data=df,kde=True)
sns.histplot(x = transformed_col_index,ax=ax2,data=df,kde=True)

ax1.set_title('Risk Score Distribution (Boxcox Transformed)')
ax2.set_title('Cost of Living Index Distribution (Boxcox Transformed)')
sns.despine()
plt.show()

# %%
[np.mean(transformed_risk_score),np.median(transformed_risk_score),stats.mode(transformed_risk_score)[0]]
# Out:
# [1.9030401785871174, 1.9085003491773884, array([1.69327376])]

# %%
[np.mean(transformed_col_index),np.median(transformed_col_index),stats.mode(transformed_col_index)]
# Out:
# [0.1979936276266444,
#  0.1979936276250677,
#  ModeResult(mode=array([0.19799363]), count=array([8]))]

# %% [markdown]
# **Let's see what is happening in the tails of our distributions**

# %% [markdown]
# What counties are in the far right and far left?

# %%
df[transformed_risk_score < 1.4]
# Out:
#               City state_abbrv  Cost of Living Index         city_state  \
# 40      Blacksburg          VA                  94.5     Blacksburg, VA
# 56      Burlington          VT                 112.8     Burlington, VT
# 219       Lewiston          ID                  92.5       Lewiston, ID
# 261     Morgantown          WV                  88.5     Morgantown, WV
# 378  State College          PA                  99.8  State College, PA
#
#                                                geocode      county  \
# 40   Blacksburg, Montgomery County, Virginia, Unite...  Montgomery
# 56   Burlington, Chittenden County, Vermont, 05401,...  Chittenden
# 219  Lewiston, Nez Perce County, Idaho, 83501, Unit...   Nez Perce
# 261  Morgantown, Monongalia County, West Virginia, ...  Monongalia
# 378  State College, Centre County, Pennsylvania, Un...      Centre
#
#              state  state_fips  county_fips  population         area  \
# ...

# %%
df[transformed_risk_score > 2.4]
# Out:
#             City state_abbrv  Cost of Living Index       city_state  \
# 52   Brownsville          TX                  87.8  Brownsville, TX
# 170      Houston          TX                  95.8      Houston, TX
# 328    Riverside          CA                 116.1    Riverside, CA
# 442  Los Angeles          CA                 140.6  Los Angeles, CA
# 448   Fort Myers          FL                 101.5   Fort Myers, FL
# 455        Miami          FL                 110.1        Miami, FL
#
#                                                geocode       county  \
# 52   Brownsville, Cameron County, Texas, United States      Cameron
# 170       Houston, Harris County, Texas, United States       Harris
# 328  Riverside, Riverside County, California, Unite...    Riverside
# 442  Los Angeles, Los Angeles County, California, U...  Los Angeles
# 448     Fort Myers, Lee County, Florida, United States          Lee
# 455   Miami, Miami-Dade County, Florida, United States   Miami-Dade
#
# ...

# %%
df[transformed_col_index < (np.percentile(transformed_col_index, 25))].head()
# Out:
#             City state_abbrv  Cost of Living Index        city_state  \
# 3     Alamogordo          NM                  85.8    Alamogordo, NM
# 4         Albany          GA                  87.3        Albany, GA
# 14      Anniston          AL                  85.7      Anniston, AL
# 17     Ashtabula          OH                  87.4     Ashtabula, OH
# 29  Battle Creek          MI                  85.9  Battle Creek, MI
#
#                                               geocode     county       state  \
# 3   Alamogordo, Otero County, New Mexico, 88310, U...      Otero  New Mexico
# 4   Albany, Dougherty County, Georgia, 31701, Unit...  Dougherty     Georgia
# 14  Anniston, Calhoun County, Alabama, 36202, Unit...    Calhoun     Alabama
# 17  Ashtabula, Ashtabula County, Ohio, 44004, Unit...  Ashtabula        Ohio
# 29  Battle Creek, Calhoun County, Michigan, 49014:...    Calhoun    Michigan
#
#     state_fips  county_fips  population         area  risk_score  \
# ...

# %%
# Out:
# 4.7099435462882866e-11
